# %%
# %pip install numpy pandas matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Could not find platform independent libraries <prefix>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('exp-1_train.csv')

# %%
data.describe()
# Out:
#                  x           y
# count   700.000000  699.000000
# mean     54.985939   49.939869
# std     134.681703   29.109217
# min       0.000000   -3.839981
# 25%      25.000000   24.929968
# 50%      49.000000   48.973020
# 75%      75.000000   74.929911
# max    3530.157369  108.871618

# %%
# Boxplot for column 'x'
data.boxplot(column=['x'])
plt.title('Boxplot of x')
plt.show()

# Boxplot for column 'y'
data.boxplot(column=['y'])
plt.title('Boxplot of y')
plt.show()

# %%
plt.scatter(data['x'], data['y'])
plt.xlabel('x')
plt.ylabel('y')
plt.title('Scatter plot of x vs y')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
def hypotheses(theta_array, x):
    return theta_array[0] + theta_array[1] * x

# %%
def cost_function(theta_array, x, y, m):
    return (1 / ( 2 * m ) * np.sum((hypotheses(theta_array, x) - y) ** 2))

# %%
def gradient_descent(x, y, theta_array, alpha, m):
    summation_0=0
    summation_1=0
    for i in range(m):
        summation_0 += ((theta_array[0]+theta_array[1]*x[i]) - y[i])
        summation_1 += ((theta_array[0]+theta_array[1]*x[i]) - y[i]) * x[i]
    new_theta_0 = theta_array[0] - (alpha / m) * summation_0
    new_theta_1 = theta_array[1] - (alpha / m) * summation_1
    updated_new_theta = np.array([new_theta_0, new_theta_1])
    return updated_new_theta

# %%
def training(x, y, alpha, iterations):
    theta0 = 0
    theta1 = 0
    theta_array = np.array([theta0, theta1])
    cost_values = []
    m = len(x)
    for i in range(iterations):
        theta_array = gradient_descent(x, y, theta_array, alpha, m)
        cost_values.append(cost_function(theta_array, x, y, m))
        y_pred = x*theta_array[1] + theta_array[0]
        plt.plot(x, y_pred, color='red', label='Regression Line')
        plt.scatter(x, y, color='blue', label='Data Points')
        plt.show()
    return cost_values

# %%
training_data = data.dropna()
training_data.shape
# Out:
# (699, 2)

# %%
x_values = training_data['x'].values
x_values = x_values.reshape(x_values.size)
y_values = training_data['y'].values
y_values = y_values.reshape(y_values.size)

# %%
alpha = 0.0001
iterations = 50
cost_values=training(x_values, y_values, alpha, iterations)
x_axis = np.arange(0, iterations, 1)
plt.plot(x_axis, cost_values, color='green')
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Cost Function Over Iterations')
plt.show()

# %% [markdown]
# observe the loss function  curve for alpha =0.00000001, 0.000001,0.01,1,5,10,100

# %%
alpha = 0.00000001
iterations = 50
cost_values=training(x_values, y_values, alpha, iterations)
x_axis = np.arange(0, iterations, 1)
plt.plot(x_axis, cost_values, color='green')
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Cost Function Over Iterations')
plt.show()

# %% [markdown]
# The graph shows the cost (loss) function value over 50 iterations of gradient descent with a very small learning rate (alpha = 1e-8). The cost decreases very slowly and almost linearly, indicating that the learning rate is too small for efficient convergence. As a result, the model parameters are updated only slightly in each iteration, and the algorithm requires many more iterations to reach the minimum cost. This demonstrates the importance of choosing an appropriate learning rate for faster and more effective training.

# %%
alpha = 0.01
iterations = 50
cost_values=training(x_values, y_values, alpha, iterations)
x_axis = np.arange(0, iterations, 1)
plt.plot(x_axis, cost_values, color='green')
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Cost Function Over Iterations')
plt.show()

# %%
alpha = 1
iterations = 50
cost_values=training(x_values, y_values, alpha, iterations)
x_axis = np.arange(0, iterations, 1)
plt.plot(x_axis, cost_values, color='green')
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Cost Function Over Iterations')
plt.show()
# Out:
# c:\Users\JAHNVI AGHERA\Desktop\SEM 5\ML\GitHub\ML\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\JAHNVI AGHERA\AppData\Local\Temp\ipykernel_26488\3512108438.py:2: RuntimeWarning: overflow encountered in square
#   return (1 / ( 2 * m ) * np.sum((hypotheses(theta_array, x) - y) ** 2))
